# %% [markdown]
# # Análise Comparativa entre conjuntos de dados

# %% [markdown]
# 🟢 Comparar resultados entre os conjuntos de dados
#
# 🟢 Análises estatíticas entre os cenários da evasão
#
# 🟢 Resultados obtidos pelo classificador SVM
#
# 🟢 Cenários que podem influenciar as áreas distintas dos cursos
